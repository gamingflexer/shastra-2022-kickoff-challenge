# %%
import pandas as pd
import csv
from pandas_profiling import ProfileReport
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
#player’s commercial value
#improve player performance, prevent injuries and increase their commercial efficiency
#based on their skill-set and performance history.

data = pd.read_csv('/Users/cosmos/Desktop/ME/Projects/shstra/kick-off/new.csv')

# %%
data.info()
data.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37548 entries, 0 to 37547
# Columns: 104 entries, Unnamed: 0 to rb
# dtypes: float64(16), int64(40), object(48)
# memory usage: 29.8+ MB
#        Unnamed: 0  sofifa_id  player_url  short_name  long_name    age    dob  \
# 0           False      False       False       False      False  False  False
# 1           False      False       False       False      False  False  False
# 2           False      False       False       False      False  False  False
# 3           False      False       False       False      False  False  False
# 4           False      False       False       False      False  False  False
# ...           ...        ...         ...         ...        ...    ...    ...
# 37543       False      False       False       False      False  False  False
# 37544       False      False       False       False      False  False  False
# 37545       False      False       False       False      False  False  False
# ...

# %% [markdown]
# PANDAS PROFILING

# %%
profile = ProfileReport (data, title=' Pandas Profiling Report', explorative=True)
profile.to_widgets()
profile.to_file('DA.html')
# Out:
# Summarize dataset:  63%|██████▎   | 74/117 [00:04<00:02, 15.52it/s, Describe variable:goalkeeping_diving]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2h/lw5rv90j0ln7v084d1vkrcg80000gn/T/ipykernel_85430/1658409710.py in <module>
#       1 profile = ProfileReport (data, title=' Pandas Profiling Report', explorative=True)
# ----> 2 profile.to_widgets()
#       3 profile.to_file('DA.html')
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/pandas_profiling/profile_report.py in to_widgets(self)
#     416         from IPython.core.display import display
#     417
# --> 418         display(self.widgets)
#     419
#     420     def _repr_html_(self) -> None:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/pandas_profiling/profile_report.py in widgets(self)
# ...

# %%
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
#plotting

graph=data.groupby('age')['value'].mean()
graph.plot(figsize=(6,4))
# Out:
# <AxesSubplot:xlabel='age'>

# %%
#data = data.fillna(data.mean()) # or add 0 next time
data['attacking_finishing'][11]
# Out:
# 55

# %%
# added all cloumns and pre processed the data
m = 'defending_sliding_tackle'
for i in data[m].index:
    data[m][i]=re.sub(r'\-.*',"",data[m][i])
    i+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2h/lw5rv90j0ln7v084d1vkrcg80000gn/T/ipykernel_85430/3050719868.py in <module>
#       2 m = 'defending_sliding_tackle'
#       3 for i in data[m].index:
# ----> 4     data[m][i]=re.sub(r'\-.*',"",data[m][i])
#       5     i+1
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: cannot use a string pattern on a bytes-like object

# %%
# Method - 2 

def clean_values(x):
    try:
        if len(x)>2:
            y = x[:2]
            return y
        else:
            return x
    except TypeError:
        return x

player_attributes_df = pd.read_csv("/Users/cosmos/Desktop/ME/Projects/Datasets/kick-off/FIFA_test_player_data.csv", index_col=0)
#DROP THE COLUMNS UNNEDDED
# position_fifa_df.drop(["Age", "Nationality", "Overall", "Potential", "Club", "Value", "Wage", "Special"],1,inplace=True)
#player_attributes_df.drop(["ID"],1,inplace=True)
X = player_attributes_df.copy()

for col in X.columns:
    X[col] = X[col].apply(lambda x : clean_values(x))
for col in X.columns:
    X[col] = X[col].astype(float)
print(len(X.index))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2h/lw5rv90j0ln7v084d1vkrcg80000gn/T/ipykernel_69213/856118982.py in <module>
#      19     X[col] = X[col].apply(lambda x : clean_values(x))
#      20 for col in X.columns:
# ---> 21     X[col] = X[col].astype(float)
#      22 print(len(X.index))
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
# ...

# %%
data.to_csv('new.csv')

# %%
#can play with work rate
skills_cols = ['age',
 'height_cm',
 'weight_kg',
 'overall',
 'potential',
 'international_reputation',
 'weak_foot',
 'skill_moves',
 'pace',
 'shooting',
 'passing',
 'dribbling',
 'defending',
 'gk_diving',
 'gk_handling',
 'gk_kicking',
 'gk_reflexes',
 'gk_speed',
 'gk_positioning',
 'attacking_crossing',
 'attacking_finishing',
 'attacking_heading_accuracy',
 'attacking_short_passing',
 'attacking_volleys',
 'skill_dribbling',
 'skill_curve',
 'skill_fk_accuracy',
 'skill_long_passing',
 'skill_ball_control',
 'movement_acceleration',
 'movement_sprint_speed',
 'movement_agility',
 'movement_reactions',
 'movement_balance',
 'power_shot_power',
 'power_jumping',
 'power_stamina',
 'power_strength',
 'power_long_shots',
 'mentality_aggression',
 'mentality_interceptions',
 'mentality_positioning',
 'mentality_vision',
 'mentality_penalties',
 'mentality_composure',
 'defending_marking',
 'defending_standing_tackle',
 'defending_sliding_tackle']


# making a custom transformer

from sklearn.base import BaseEstimator, TransformerMixin

class CustomTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, Columns):
        self.Columns=Columns
        
    def fit(self,X,y=None):
        return self
    
    def transform(self,X):
        New_X=X.copy()
        New_X=New_X[self.Columns].copy()
        return New_X

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler #standirize values
from sklearn.impute import SimpleImputer #fill in missing values

#adding parameters
pipeline=Pipeline([
    ('custom_tr', CustomTransformer(skills_cols)),
    ('imputer',SimpleImputer(strategy='median')),
    ('std_scaler',StandardScaler())
])

# %%
X = pipeline.fit_transform(data)
y = data['value'].copy()
y = y.values/1000000

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=2)

# %%
X_test
# Out:
# array([[-0.04590622,  0.55056383,  0.95507368, ...,  0.14170782,
#          0.4343945 ,  0.30112765],
#        [-0.04590622, -0.49128039,  1.09742881, ..., -0.92558546,
#         -0.3928921 , -0.49329854],
#        [ 0.38367299, -1.97962929, -1.03789807, ..., -0.05234551,
#          0.1586323 ,  0.06747288],
#        ...,
#        [-0.47548542,  0.84823361, -0.46847757, ...,  0.72386778,
#          0.5722756 ,  0.72170622],
#        [-1.54943344,  0.10405916, -1.60731857, ..., -0.44045215,
#         -0.8065354 , -0.68022235],
#        [-1.11985424,  1.59240806,  2.09391469, ..., -1.4592321 ,
#         -1.26613907, -1.24099378]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model_lr = LinearRegression()
model_lr.fit(X_train,y_train)

predictions=model_lr.predict(X_test)
mse=mean_squared_error(y_test, predictions)
rmse=np.sqrt(mse)
rmse

#tryping linear regresiion model
# Out:
# 3.434971029591626

# %%
#label encoder
from sklearn import preprocessing
from sklearn import utils

lab_enc = preprocessing.LabelEncoder()
encoded =lab_enc.fit_transform(y_train.astype('int'))

# %%
#trying random forest algo

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid=[
    {'n_estimators':[3,10,30], 'max_features':[2,4,6,8,10]},
    {'bootstrap':[False],'n_estimators':[3,10],'max_features':[2,3,4,6]}
]
forest_reg=RandomForestRegressor()

grid_search=GridSearchCV(forest_reg, param_grid, cv=5,
                        scoring='neg_mean_squared_error',
                        return_train_score=True)

grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_features': [2, 4, 6, 8, 10],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4, 6],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
print(grid_search.best_params_, np.sqrt(-grid_search.best_score_))
# Out:
# {'max_features': 10, 'n_estimators': 30} 1.045051441547488

# %%
feature_importances=grid_search.best_estimator_.feature_importances_
features=sorted(zip(feature_importances, skills_cols),reverse=True)
features_sorted=np.array(features)
features_sorted
# Out:
# array([['0.26877754546953836', 'overall'],
#        ['0.19449066765079487', 'potential'],
#        ['0.1088314254181691', 'movement_reactions'],
#        ['0.09497971414600274', 'skill_ball_control'],
#        ['0.05102518688258095', 'skill_dribbling'],
#        ['0.037097159634603194', 'mentality_composure'],
#        ['0.03318442086883381', 'international_reputation'],
#        ['0.02641811832377157', 'dribbling'],
#        ['0.02317086059400372', 'attacking_short_passing'],
#        ['0.02243676774149223', 'shooting'],
#        ['0.019004064470840694', 'age'],
#        ['0.017766478042741382', 'mentality_positioning'],
#        ['0.01232611607480706', 'mentality_interceptions'],
#        ['0.01072924768764737', 'defending'],
#        ['0.01065077711069517', 'defending_standing_tackle'],
#        ['0.004457611805086684', 'mentality_vision'],
#        ['0.00433358827450571', 'attacking_finishing'],
#        ['0.003888846508026415', 'attacking_volleys'],
# ...

# %%
plt.pie(features_sorted[:,0], labels=features_sorted[:,1],radius=5,autopct='%1.1f%%')
plt.show()

# %%
#save sklearn model using pickle
import pickle

final_model = grid_search.best_estimator_
pickle.dump(final_model, open('random_search_best.sav','wb'))

# %%
#load the model
import pickle
lodded_model = pickle.load(open('/Users/cosmos/Desktop/ME/Projects/shstra/models/random_search_best.sav','rb'))

#results = lodded_model.score(X_test, y_test)
#print(results)

# %% [markdown]
# Testing data as per kaggle hackathon

# %%
import pandas as pd
import re
test_info = pd.read_csv('/Users/cosmos/Desktop/ME/Projects/shstra/kick-off/FIFA_test_player_data.csv')
#test_ids = pd.read_csv('/Users/cosmos/Desktop/ME/Projects/Datasets/kick-off/FIFA_test.csv')
test_ids = pd.read_csv('/Users/cosmos/Desktop/ME/Projects/shstra/final_PP_data.csv')
test_ids
# Out:
#       Unnamed: 0       0       1       2       3       4       5       6  \
# 0              0  238577  189730  212616  209729  246565  233090    8631
# 1              1  227675  177793  199511  204387  199964  244727  176619
# 2              2  199522  225810  227740  243139  229771  183475  198970
# 3              3  223953  222399  231307  196143  212814  244794  208335
# 4              4   53110  229137  213887  179891  228595  211736  243305
# ...          ...     ...     ...     ...     ...     ...     ...     ...
# 1457        1457  239090  227770  211245  233085  232017  222428  163761
# 1458        1458  220994  231733  205340  240738  241743  239402  233804
# 1459        1459  228419  224344  222599  210690  209440  231131  186745
# 1460        1460  205496  223306  210007  232110  192641  237764  206053
# 1461        1461  227767  239049  240282  234383  192188  189944  243222
#
#            7       8       9      10
# 0     216047  196143  247728  238577
# ...

# %%
new_ids=test_ids['player_ids'].str.split(',', expand=True)
new_ids
# Out:
#            0        1        2        3        4        5        6        7   \
# 0     [238577   189730   212616   209729   246565   233090     8631   216047
# 1     [227675   177793   199511   204387   199964   244727   176619   169181
# 2     [199522   225810   227740   243139   229771   183475   198970   170084
# 3     [223953   222399   231307   196143   212814   244794   208335   173305
# 4      [53110   229137   213887   179891   228595   211736   243305   228886
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1457  [239090   227770   211245   233085   232017   222428   163761   206134
# 1458  [220994   231733   205340   240738   241743   239402   233804   226051
# 1459  [228419   224344   222599   210690   209440   231131   186745   237726
# 1460  [205496   223306   210007   232110   192641   237764   206053   181318
# 1461  [227767   239049   240282   234383   192188   189944   243222   252542
#
#            8        9         10
# ...

# %%
new_ids[0]=new_ids[0].map(lambda x :x.lstrip('['))
new_ids[10]=new_ids[0].map(lambda x :x.lstrip(']'))
new_ids.to_csv('final_PP_data.csv')

# %% [markdown]
# Iteration of ids

# %%
test1
lodded_model.predict(test1)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/sklearn/base.py:438: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2h/lw5rv90j0ln7v084d1vkrcg80000gn/T/ipykernel_80672/2475815816.py in <module>
# ----> 1 lodded_model.predict(test_info.head(1))
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     959         check_is_fitted(self)
#     960         # Check data
# --> 961         X = self._validate_X_predict(X)
#     962
#     963         # Assign chunk of trees to jobs
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
# ...

# %%
#from kaggle thanks to owner!
from math import pi
idx = 1
plt.figure(figsize=(15,45))
for position_name, features in data.groupby(data['player_positions'])[skills_cols].mean().iterrows():
    top_features = dict(features.nlargest(5))
    
    # number of variable
    categories=top_features.keys()
    N = len(categories)

    # We are going to plot the first line of the data frame.
    # But we need to repeat the first value to close the circular graph:
    values = list(top_features.values())
    values += values[:1]

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(10, 3, idx, polar=True)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=8)
    
    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([25,50,75], ["25","50","75"], color="grey", size=7)
    plt.ylim(0,100)
    
    plt.subplots_adjust(hspace = 0.5)
    
    # Plot data
    ax.plot(angles, values, linewidth=1, linestyle='solid')

    # Fill area
    ax.fill(angles, values, 'b', alpha=0.1)
    
    plt.title(position_name, size=11, y=1.1)
    
    idx += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2h/lw5rv90j0ln7v084d1vkrcg80000gn/T/ipykernel_69213/3970173978.py in <module>
#      19
#      20     # Initialise the spider plot
# ---> 21     ax = plt.subplot(10, 3, idx, polar=True)
#      22
#      23     # Draw one axe per variable + add labels labels yet
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1266
#    1267     # First, search for an existing subplot with a matching spec.
# -> 1268     key = SubplotSpec._from_subplot_args(fig, args)
#    1269
#    1270     for ax in fig.axes:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     606         else:
# ...

# %% [markdown]
# NEURAL NETWORK

# %%
from sklearn.neural_network import MLPRegressor

clf = MLPRegressor(hidden_layer_sizes= (40,40,40), random_state=1, alpha =0.01,max_iter=1, warm_start=True)

licz= []
accu = []
loss =[]
test = []

for i in range(150):
    clf.fit(X_train,y_train)
    licz.append(i)
    accu.append(clf.score(X_train,y_train))
    loss.append(clf.loss_)
    test.append(clf.score(X= X_test,y = y_test))
    if i%10==0:
         print("iter",i,"\taccuracy",clf.score(X_train, y_train),"\test",clf.score(X= X_test,y = y_test),"\tloss",clf.loss_)

import matplotlib.pyplot as plt
print(clf.score(X= X_test,y = y_test))
plt.plot(licz[5:],accu[5:],test[5:])
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   warnings.warn(
# iter 0 	accuracy 0.8063452923071106 	est 0.8034017275946038 	loss 8.338038586238193
# iter 10 	accuracy 0.974008595901713 	est 0.9721422936148184 	loss 0.5447626396864991
# iter 20 	accuracy 0.9821190090465258 	est 0.9817022322099284 	loss 0.35566443538776293
# iter 30 	accuracy 0.9844515813194952 	est 0.98167941522411 	loss 0.29652871851066287
# iter 40 	accuracy 0.9844638530327525 	est 0.980377099776403 	loss 0.2519150703364761
# iter 50 	accuracy 0.9871916336856998 	est 0.983621464720476 	loss 0.22427690086148086
# iter 60 	accuracy 0.9872129565542042 	est 0.9832219631356367 	loss 0.2066560799184203
# iter 70 	accuracy 0.9880282256141912 	est 0.9838807238786994 	loss 0.2009585270653746
# ...
